# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems-75/blob/main/Problem72.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution(object):
    def minDistance(self, word1, word2):
        """
        :type word1: str
        :type word2: str
        :rtype: int
        """

        m = len(word1)
        n = len(word2)

        dp = [[0] * (n + 1) for _ in range(m + 1)]

        # Update the first row
        for i in range(len(dp)):
            dp[i][0] = i

        # Update the first column
        for i in range(len(dp[0])):
            dp[0][i] = i

        for i in range(1, m + 1):
            for j in range(1, n + 1):
                # Move diagonally without a cost
                if word1[i - 1] == word2[j - 1]:
                    dp[i][j] = dp[i - 1][j - 1]

                else:
                    # We can do Insert, Delete or Replace
                    dp[i][j] = 1 + min(
                        dp[i - 1][j],
                        dp[i][j - 1],
                        dp[i - 1][j - 1]
                    )

        return dp[-1][-1]

# %%
solution = Solution()

# %%
word1 = "horse"
word2 = "ros"

print(solution.minDistance(word1, word2))
# Out:
# 3

# %%
word1 = "intention"
word2 = "execution"

print(solution.minDistance(word1, word2))
# Out:
# 5

# %%
word1 = ""
word2 = ""

print(solution.minDistance(word1, word2))
# Out:
# 0

# %%
word1 = "abc"
word2 = ""

print(solution.minDistance(word1, word2))
# Out:
# 3

# %%
word1 = ""
word2 = "def"

print(solution.minDistance(word1, word2))
# Out:
# 3

# %%
word1 = "abc"
word2 = "abc"

print(solution.minDistance(word1, word2))
# Out:
# 0

# %%
word1 = "abcdef"
word2 = "abc"

print(solution.minDistance(word1, word2))
# Out:
# 3

# %%
word1 = "def"
word2 = "abcdef"

print(solution.minDistance(word1, word2))
# Out:
# 3

# %%
word1 = "abcdef"
word2 = "bdf"

print(solution.minDistance(word1, word2))
# Out:
# 3

# %%
word1 = "abc"
word2 = "cab"

print(solution.minDistance(word1, word2))
# Out:
# 2
