# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems-75/blob/main/Problem2215_Improved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution(object):
    def findDifference(self, nums1, nums2):
        """
        :type nums1: List[int]
        :type nums2: List[int]
        :rtype: List[List[int]]
        """

        # Time Complexity: O(N)
        # Spcae Compexity: O(N)

        # Convert to sets to get distinct values
        s1, s2 = set(nums1), set(nums2)

        return [list(s1- s2), list(s2 - s1)]

# %%
solution = Solution()

# %%
nums1 = [1,2,3]
nums2 = [2,4,6]

print(solution.findDifference(nums1, nums2))
# Out:
# [[1, 3], [4, 6]]

# %%
nums1 = [1,2,3,3]
nums2 = [1,1,2,2]

print(solution.findDifference(nums1, nums2))
# Out:
# [[3], []]

# %%
nums1 = [1]
nums2 = [2]

print(solution.findDifference(nums1, nums2))
# Out:
# [[1], [2]]

# %%
nums1 = [1]
nums2 = [1]

print(solution.findDifference(nums1, nums2))
# Out:
# [[], []]
