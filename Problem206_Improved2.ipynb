# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems-75/blob/main/Problem206_Improved2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Definition for singly-linked list.
class ListNode(object):
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

# %%
class Solution(object):
    def reverseList(self, head):
        """
        :type head: Optional[ListNode]
        :rtype: Optional[ListNode]
        """

        # The recursive Approach

        # Base case: empty list or last node
        if not head or not head.next:
            return head

        # Recursive step: reverse the rest of the list
        new_head = self.reverseList(head.next)

        # Point the next node's next back to myself
        head.next.next = head
        head.next = None

        return new_head
