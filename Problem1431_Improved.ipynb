# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems-75/blob/main/Problem1431_Improved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution(object):
    def kidsWithCandies(self, candies, extraCandies):
        """
        :type candies: List[int]
        :type extraCandies: int
        :rtype: List[bool]
        """

        max_c  = max(candies)

        return [c + extraCandies >= max_c for c in candies]

# %%
solution = Solution()

# %%
candies = [2,3,5,1,3]
extraCandies = 3

print(solution.kidsWithCandies(candies, extraCandies))
# Out:
# [True, True, True, False, True]

# %%
candies = [4,2,1,1,2]
extraCandies = 1

print(solution.kidsWithCandies(candies, extraCandies))
# Out:
# [True, False, False, False, False]

# %%
candies = [12,1,12]
extraCandies = 10

print(solution.kidsWithCandies(candies, extraCandies))
# Out:
# [True, False, True]
