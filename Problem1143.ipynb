# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems-75/blob/main/Problem1143.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution(object):
    def longestCommonSubsequence(self, text1, text2):
        """
        :type text1: str
        :type text2: str
        :rtype: int
        """

        # Number of rows
        rows = len(text1)

        # Number of columns
        cols = len(text2)

        # We add +1 for cols and rows for convenience
        dp = [[0] * (cols + 1) for _ in range(rows + 1)]

        for i in range(1, rows + 1):
            for j in range(1, cols + 1):
                if text1[i - 1] == text2[j - 1]:
                    # We add 1 to the top right cell value to account for the sequence.
                    dp[i][j] = dp[i - 1][j - 1] + 1

                else:
                    dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])

        return dp[-1][-1]

# %%
solution = Solution()

# %%
text1 = "abcde"
text2 = "ace"

print(solution.longestCommonSubsequence(text1, text2))
# Out:
# 3

# %%
text1 = "abc"
text2 = "abc"

print(solution.longestCommonSubsequence(text1, text2))
# Out:
# 3

# %%
text1 = "abc"
text2 = "def"

print(solution.longestCommonSubsequence(text1, text2))
# Out:
# 0

# %%
text1 = "xvnmaiopblllck"
text2 = "eefgadgeczz"

print(solution.longestCommonSubsequence(text1, text2))
# Out:
# 2

# %%
text1 = "abc"
text2 = "cba"

print(solution.longestCommonSubsequence(text1, text2))
# Out:
# 1

# %%
text1 = "bsbininm"
text2 = "jmjkbkjkv"

print(solution.longestCommonSubsequence(text1, text2))
# Out:
# 1

# %%
text1 = "bsranicm"
text2 = "jmjkqacbv"

print(solution.longestCommonSubsequence(text1, text2))
# Out:
# 2
