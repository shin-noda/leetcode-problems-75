# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems-75/blob/main/Problem206.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Definition for singly-linked list.
class ListNode(object):
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

# %%
class Solution(object):
    def reverseList(self, head):
        """
        :type head: Optional[ListNode]
        :rtype: Optional[ListNode]
        """

        # Check if there are at least 2 nodes
        if not head or not head.next:
            return head

        # This is gonna be the last node
        tail = head
        head = head.next

        # Disconnect the node
        tail.next = None

        curr = None
        while head:
            curr = head
            head = head.next

            curr.next = tail
            tail = curr

        return curr
