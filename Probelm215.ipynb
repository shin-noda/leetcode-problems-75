# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems-75/blob/main/Probelm215.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class MinHeap:
    def __init__(self):
        self.heap = []


    def insert(self, value):
        # Add to the end
        self.heap.append(value)
        self._heapify_up(len(self.heap) - 1)


    def extract_min(self):
        if not self.heap:
            return None

        if len(self.heap) == 1:
            return self.heap.pop()

        # Swap root with last
        min_val = self.heap[0]
        self.heap[0] = self.heap.pop()

        # Restore heap property
        self._heapify_down(0)

        return min_val


    def _heapify_up(self, index):
        while index > 0:
            parent = (index - 1) // 2

            if self.heap[index] < self.heap[parent]:
                self.heap[index], self.heap[parent] = self.heap[parent], self.heap[index]
                index = parent

            else:
                break


    def _heapify_down(self, index):
        size = len(self.heap)

        while True:
            left = 2 * index + 1
            right = 2 * index + 2
            smallest = index

            if left < size and self.heap[left] < self.heap[smallest]:
                smallest = left

            if right < size and self.heap[right] < self.heap[smallest]:
                smallest = right

            if smallest == index:
                break

            self.heap[index], self.heap[smallest] = self.heap[smallest], self.heap[index]
            index = smallest


    def peek(self):
        if self.heap:
            return self.heap[0]

        return None


class Solution(object):
    def findKthLargest(self, nums, k):
        """
        :type nums: List[int]
        :type k: int
        :rtype: int
        """

        min_heap = MinHeap()

        # Create a Min Heap with k elements
        # Insert first k elements of nums
        for i in range(k):
            min_heap.insert(nums[i])

        # Iterate the rest of the elements in nums
        for i in range(k, len(nums)):
            if min_heap.peek() < nums[i]:
                # Insert a new value
                min_heap.insert(nums[i])

                # Remove the smallest value
                min_heap.extract_min()

        return min_heap.peek()

# %%
solution = Solution()

# %%
nums = [3,2,1,5,6,4]
k = 2

print(solution.findKthLargest(nums, k))

# %%
nums = [3,2,3,1,2,4,5,5,6]
k = 4

print(solution.findKthLargest(nums, k))
