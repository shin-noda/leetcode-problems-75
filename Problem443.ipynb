# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems-75/blob/main/Problem443.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution(object):
    def compress(self, chars):
        """
        :type chars: List[str]
        :rtype: int
        """
        # Note: we have to solve this problem using only constant extra space,
        # so we don't actually store results on string since it's O(N)

        result = 0

        i = 0
        while i < len(chars):
            ch = chars[i]

            if i + 1 >= len(chars) or i + 1 < len(chars) and ch != chars[i + 1]:
                # Modify the input
                chars[result] = ch
                result += 1

            else:
                streak = 1
                while i + 1 < len(chars) and ch == chars[i + 1]:
                    i += 1
                    streak += 1

                # Find the number of digits of the steak.
                # e.g. streak = 5 -> 1 digit, so add 1 to result.
                # streak = 12 -> 2 digits, so add 2 to result.
                # streak 710 -> 3 digits, so add 3 to result.

                # Update chars
                chars[result] = ch
                result += 1

                num_swap = 0
                while streak > 0:
                    chars[result] = str(streak % 10)
                    streak = streak // 10

                    # We swap number later
                    num_swap += 1

                    # We swap the numbers
                    result += 1

                # Swapping
                for j in range(num_swap // 2):
                    chars[result - num_swap + j], chars[result - 1 - j] = chars[result - 1 - j], chars[result - num_swap + j]

            i += 1

        print(chars)

        return result

# %%
solution = Solution()

# %%
chars = ["a","a","b","b","c","c","c"]

print(solution.compress(chars))
# Out:
# ['a', '2', 'b', '2', 'c', '3', 'c']
# 6

# %%
chars = ["a"]

print(solution.compress(chars))
# Out:
# ['a']
# 1

# %%
chars = ["a","b","b","b","b","b","b","b","b","b","b","b","b"]

print(solution.compress(chars))
# Out:
# ['a', 'b', '1', '2', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b']
# 4

# %%
chars = ["a","a","b","b","b","b","b","b","b","b","b","b","b","b"]

print(solution.compress(chars))
# Out:
# ['a', '2', 'b', '1', '2', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b']
# 5

# %%
chars = ["a","b","c"]

print(solution.compress(chars))
# Out:
# ['a', 'b', 'c']
# 3

# %%
chars = ["a","a","b","b","b","b","b","b","b","b","b","b","b","b","c","c","c","d","e","e"]

print(solution.compress(chars))
# Out:
# ['a', '2', 'b', '1', '2', 'c', '3', 'd', 'e', '2', 'b', 'b', 'b', 'b', 'c', 'c', 'c', 'd', 'e', 'e']
# 10

# %%
chars = ["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"]

print(solution.compress(chars))
# Out:
# ['a', '1', '0', '0', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# 4

# %%
3 0 0 1
# Out:
#   File "/tmp/ipykernel_20128/3032220232.py", line 1
#     3 0 0 1
#       ^
# SyntaxError: invalid syntax
