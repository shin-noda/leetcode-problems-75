# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems-75/blob/main/Problem11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution(object):
    def maxArea(self, height):
        """
        :type height: List[int]
        :rtype: int
        """

        # Use a two-pointer method.
        left, right = 0, len(height) - 1

        # We calculate the amount of water as:
        # (right - left) * min(height(right), height(left))
        water = 0

        while left < right:
            # Calculate the amount of water
            water = max(water, (right - left) * min(height[right], height[left]))

            # Check which bar is taller.
            if height[left] < height[right]:
                left += 1

            else:
                right -= 1

        return water

# %%
solution = Solution()

# %%
height = [1,8,6,2,5,4,8,3,7]

print(solution.maxArea(height))
# Out:
# 49

# %%
height = [1,1]

print(solution.maxArea(height))
# Out:
# 1

# %%
height = [8,7,2,1]


print(solution.maxArea(height))
# Out:
# 7
