# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems-75/blob/main/Problem104.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Definition for a binary tree node.
class TreeNode(object):
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

# %%
class Solution(object):
    def maxDepth(self, root):
        """
        :type root: Optional[TreeNode]
        :rtype: int
        """

        # Check if there are nodes
        if not root:
            return 0

        # Use DFS
        queue = [root]
        pointer = 0
        depth = 0

        while pointer < len(queue):
            n = len(queue) - pointer

            for _ in range(pointer, len(queue)):
                node = queue[pointer]

                if node.left:
                    queue.append(node.left)

                if node.right:
                    queue.append(node.right)

                pointer += 1

            depth += 1

        return depth
