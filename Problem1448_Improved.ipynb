# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problems-75/blob/main/Problem1448_Improved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Definition for a binary tree node.
class TreeNode(object):
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

# %%
class Solution(object):
    def goodNodes(self, root):
        """
        :type root: TreeNode
        :rtype: int
        """

        # Check if root exists
        if not root:
            return 0

        stack = [(root, root.val)]
        good_count = 0

        while stack:
            node, max_so_far = stack.pop()

            # Check if the current node is good
            if node.val >= max_so_far:
                good_count += 1

            # Update the max for the children
            new_max = max(max_so_far, node.val)

            # Push children to the stack
            if node.right:
                stack.append((node.right, new_max))

            if node.left:
                stack.append((node.left, new_max))

        return good_count
